# %%
import pandas as pd
import re

df_fateh=pd.read_csv("al-fateh-products.csv")
df_imtiaz=pd.read_csv("Imtiaz-products.csv")
df_jalalsons=pd.read_csv("jalal-sons-products.csv")
df_metro=pd.read_csv("Metro-products.csv")

# %% [markdown]
# we are gonna create cleaned_catgories for all stores (canonicalization of categories)

# %% [markdown]
# for fateh

# %%
print("shape of fateh data frame:")
print(df_fateh.shape)


print("Sample data from fateh data frame:")
display(df_fateh.sample(10))

print("categories in fateh data frame:")
fateh_categories=df_fateh['category'].value_counts()
print(fateh_categories)

pattern=r' +'
replacement=r'_'
fateh_categories_json=dict.fromkeys([ re.sub(pattern, replacement, c.lower()) + "---fateh" for c in fateh_categories.index])
print(fateh_categories_json)
# Out:
# shape of fateh data frame:
# (4676, 7)
# Sample data from fateh data frame:
#       Unnamed: 0     store                  category  \
# 2444        2444  al-fateh           Noodles & Pasta
# 2399        2399  al-fateh           Noodles & Pasta
# 1373        1373  al-fateh             Rice Products
# 1737        1737  al-fateh                Chocolates
# 1837        1837  al-fateh                Chocolates
# 3150        3150  al-fateh  Imported Drinks & Juices
# 938          938  al-fateh              Frozen Items
# 4298        4298  al-fateh                 Tin Foods
# 1469        1469  al-fateh             Chips & Nimko
# 1140        1140  al-fateh                      Oils
#
#                                                   name     price  \
# 2444                       BORGES PASTA FARFALLE 500GM    Rs.465
# 2399                 BAKE PARLOR BALTI MACARONI 250 GM    Rs.140
# 1373                  KHICHRY BROKEN BASMATI RICE 5 KG  Rs.1,045
# 1737               CADBURY DAIRY MILK CHOCOLATE 5.2 GM     Rs.20
# 1837  WERTHERS ORIGINAL CHOCOLATE CARAMEL POUCH 100 GM  Rs.1,095
# 3150           MR FALOODA DRINK STRAWBERRY 3IN1 290 ML    Rs.345
# 938                 SUFI CHICKEN CHEESE PARATHA 560 GM    Rs.570
# 4298                     MITCHELLS TOMATO PASTE 450 GM    Rs.465
# 1469                           LAYS CHIPS SALTED 72 GM    Rs.100
# 1140                     DALDA COOKING OIL TIN 2.5 LTR  Rs.1,490
#
#                                            product-link  \
# 2444  https://alfatah.pk/products/borges-pasta-farfa...
# 2399  https://alfatah.pk/products/bake-parlor-balti-...
# 1373  https://alfatah.pk/products/khichry-broken-bas...
# 1737  https://alfatah.pk/products/cadbury-dairy-milk...
# 1837  https://alfatah.pk/products/werthers-original-...
# 3150  https://alfatah.pk/products/mr-falooda-drink-s...
# 938   https://alfatah.pk/products/sufi-chicken-chees...
# 4298  https://alfatah.pk/products/mitchells-tomato-p...
# 1469  https://alfatah.pk/products/lays-chips-salted-...
# 1140  https://alfatah.pk/products/dalda-cooking-oil-...
#
#                                               image_url
# 2444  https://cdn.shopify.com/s/files/1/0777/0954/16...
# 2399  https://cdn.shopify.com/s/files/1/0777/0954/16...
# 1373  https://cdn.shopify.com/s/files/1/0777/0954/16...
# 1737  https://cdn.shopify.com/s/files/1/0777/0954/16...
# 1837  https://cdn.shopify.com/s/files/1/0777/0954/16...
# 3150  https://cdn.shopify.com/s/files/1/0777/0954/16...
# 938   https://cdn.shopify.com/s/files/1/0777/0954/16...
# 4298  https://cdn.shopify.com/s/files/1/0777/0954/16...
# 1469  https://cdn.shopify.com/s/files/1/0777/0954/16...
# 1140  https://cdn.shopify.com/s/files/1/0777/0954/16...
# categories in fateh data frame:
# category
# Frozen Items                240
# Local Drinks                233
# Sauces & Soups              231
# Chips & Nimko               215
# Pickle & Vinegar            186
# Baking Items                185
# Noodles & Pasta             183
# Dry Fruits & Dates          171
# Tin Foods                   169
# Mayo & Spreads              166
# Teas                        165
# Imported Drinks & Juices    165
# Baby food                   163
# Candies & Bubble Gums       158
# Cheese                      156
# Cereals                     153
# Biscuits                    144
# Chocolates                  138
# Coffee                      138
# Baking Accessories          126
# Oils                        102
# Olive oil                    92
# Ice Cream                    85
# Honey                        73
# Jams                         71
# PopCorn                      67
# Rice Products                63
# Flour                        57
# Bread                        55
# Drinking water               53
# Drinking Powders             47
# Butter                       43
# Squashes                     43
# Ghee                         41
# Salt                         40
# Milk                         38
# Frozen Fries                 28
# Milk Powder & Whitener       28
# Baking Chocolates            27
# Flavoured Milk               27
# Yogurt                       24
# Dairy Creams                 20
# Rusks & Buns                 20
# Margarine                    13
# Sugar                        10
# Liquid Tin Milk              10
# Eggs                          9
# Raita                         5
# Name: count, dtype: int64
# {'frozen_items---fateh': None, 'local_drinks---fateh': None, 'sauces_&_soups---fateh': None, 'chips_&_nimko---fateh': None, 'pickle_&_vinegar---fateh': None, 'baking_items---fateh': None, 'noodles_&_pasta---fateh': None, 'dry_fruits_&_dates---fateh': None, 'tin_foods---fateh': None, 'mayo_&_spreads---fateh': None, 'teas---fateh': None, 'imported_drinks_&_juices---fateh': None, 'baby_food---fateh': None, 'candies_&_bubble_gums---fateh': None, 'cheese---fateh': None, 'cereals---fateh': None, 'biscuits---fateh': None, 'chocolates---fateh': None, 'coffee---fateh': None, 'baking_accessories---fateh': None, 'oils---fateh': None, 'olive_oil---fateh': None, 'ice_cream---fateh': None, 'honey---fateh': None, 'jams---fateh': None, 'popcorn---fateh': None, 'rice_products---fateh': None, 'flour---fateh': None, 'bread---fateh': None, 'drinking_water---fateh': None, 'drinking_powders---fateh': None, 'butter---fateh': None, 'squashes---fateh': None, 'ghee---fateh': None, 'salt---fateh': None, 'milk---fateh': None, 'frozen_fries---fateh': None, 'milk_powder_&_whitener---fateh': None, 'baking_chocolates---fateh': None, 'flavoured_milk---fateh': None, 'yogurt---fateh': None, 'dairy_creams---fateh': None, 'rusks_&_buns---fateh': None, 'margarine---fateh': None, 'sugar---fateh': None, 'liquid_tin_milk---fateh': None, 'eggs---fateh': None, 'raita---fateh': None}

# %% [markdown]
# for imtiaz

# %%
print("shape of imtiaz data frame:")
print(df_imtiaz.shape)
print("#"*50)

print("Sample data from imtiaz data frame:")
display(df_imtiaz.sample(10))
print("#"*50)

print("categories in imtiaz data frame:")
imtiaz_categories=df_imtiaz['category'].value_counts()
print(imtiaz_categories)

pattern=r' +'
replacement=r'_'
imtiaz_categories_json=dict.fromkeys([ re.sub(pattern, replacement, c.lower()) + "---imtiaz" for c in imtiaz_categories.index])
print(imtiaz_categories_json)
# Out:
# shape of imtiaz data frame:
# (247, 7)
# ##################################################
# Sample data from imtiaz data frame:
#      Unnamed: 0   store                                               name  \
# 179         179  Imtiaz                        Nurpur Butter Unsalted 200g
# 10           10  Imtiaz             Murree Brewery's Beer Malt79 N/R 250ml
# 173         173  Imtiaz                    Pakola Flavour Milk Mango 125ml
# 42           42  Imtiaz                    Quice Perfect Juice Apple 200ml
# 78           78  Imtiaz                          Imtiaz Coffee Classic 50g
# 163         163  Imtiaz                     Polac Condensed Milk Tin 1000g
# 96           96  Imtiaz                     Ponam Chana White Supreme 500g
# 223         223  Imtiaz  Listerine Mouth Wash Advanced Tartar Control 2...
# 203         203  Imtiaz         Shield Silicone Nipple Evenflo Regular 2's
# 70           70  Imtiaz                       Tapal Green Tea Gulbahar 28g
#
#                                           product-link       price  \
# 179  https://shop.imtiaz.com.pk/product/product-ite...  Rs. 749.00
# 10   https://shop.imtiaz.com.pk/product/product-ite...   Rs. 79.00
# 173  https://shop.imtiaz.com.pk/product/product-ite...   Rs. 45.00
# 42   https://shop.imtiaz.com.pk/product/product-ite...   Rs. 40.00
# 78   https://shop.imtiaz.com.pk/product/product-ite...  Rs. 899.00
# 163  https://shop.imtiaz.com.pk/product/product-ite...  Rs. 709.00
# 96   https://shop.imtiaz.com.pk/product/product-ite...  Rs. 199.00
# 223  https://shop.imtiaz.com.pk/product/product-ite...  Rs. 725.00
# 203  https://shop.imtiaz.com.pk/product/product-ite...   Rs. 70.00
# 70   https://shop.imtiaz.com.pk/product/product-ite...   Rs. 48.00
#
#                      category  \
# 179        Butter & Margarine
# 10     Carbonated Soft Drinks
# 173            Flavoured Milk
# 42           Juices & Nectars
# 78                     Coffee
# 163                      Milk
# 96            Pulses & Grains
# 223                 Oral Care
# 203  Baby Feeding Accessories
# 70                        Tea
#
#                                              image_url
# 179  https://shop.imtiaz.com.pk/_next/image?url=htt...
# 10   https://shop.imtiaz.com.pk/_next/image?url=htt...
# 173  https://shop.imtiaz.com.pk/_next/image?url=htt...
# 42   https://shop.imtiaz.com.pk/_next/image?url=htt...
# 78   https://shop.imtiaz.com.pk/_next/image?url=htt...
# 163  https://shop.imtiaz.com.pk/_next/image?url=htt...
# 96   https://shop.imtiaz.com.pk/_next/image?url=htt...
# 223  https://shop.imtiaz.com.pk/_next/image?url=htt...
# 203  https://shop.imtiaz.com.pk/_next/image?url=htt...
# 70   https://shop.imtiaz.com.pk/_next/image?url=htt...
# ##################################################
# categories in imtiaz data frame:
# category
# Juices & Nectars                    43
# Noodles & Pasta                     30
# Salt, Spices & Herbs                24
# Pulses & Grains                     21
# Butter & Margarine                  15
# Baby Feeding Accessories            12
# Baby Food                           12
# Flavoured Milk                      10
# Carbonated Soft Drinks              10
# Tea                                  9
# Tissue                               8
# Water                                7
# Tea Whiteners                        7
# Laundry                              6
# Air Fresheners & Home Fragrances     5
# Milk                                 5
# Coffee                               4
# Oral Care                            3
# Make to drink                        3
# Sports Drink                         2
# Cleaning                             2
# Diapers & Pants                      2
# Disposable                           2
# Biscuits & Wafers                    1
# Instant Tea & Coffee                 1
# Hygiene                              1
# Chilled Coffee                       1
# Skin Care                            1
# Name: count, dtype: int64
# {'juices_&_nectars---imtiaz': None, 'noodles_&_pasta---imtiaz': None, 'salt,_spices_&_herbs---imtiaz': None, 'pulses_&_grains---imtiaz': None, 'butter_&_margarine---imtiaz': None, 'baby_feeding_accessories---imtiaz': None, 'baby_food---imtiaz': None, 'flavoured_milk---imtiaz': None, 'carbonated_soft_drinks---imtiaz': None, 'tea---imtiaz': None, 'tissue---imtiaz': None, 'water---imtiaz': None, 'tea_whiteners---imtiaz': None, 'laundry---imtiaz': None, 'air_fresheners_&_home_fragrances---imtiaz': None, 'milk---imtiaz': None, 'coffee---imtiaz': None, 'oral_care---imtiaz': None, 'make_to_drink---imtiaz': None, 'sports_drink---imtiaz': None, 'cleaning---imtiaz': None, 'diapers_&_pants---imtiaz': None, 'disposable---imtiaz': None, 'biscuits_&_wafers---imtiaz': None, 'instant_tea_&_coffee---imtiaz': None, 'hygiene---imtiaz': None, 'chilled_coffee---imtiaz': None, 'skin_care---imtiaz': None}

# %% [markdown]
# for jalalsons

# %%
print("shape of jalalsons data frame:")
print(df_jalalsons.shape)
print("#"*50)

print("Sample data from jalalsons data frame:")
display(df_jalalsons.sample(10))
print("#"*50)

print("categories in jalalsons data frame:")
jalalsons_categories=df_jalalsons['category'].value_counts()
print(jalalsons_categories)

pattern=r' +'
replacement=r'_'
jalalsons_categories_json=dict.fromkeys([ re.sub(pattern, replacement, c.lower()) + "---jalalsons" for c in jalalsons_categories.index])
print(jalalsons_categories_json)
# Out:
# shape of jalalsons data frame:
# (1420, 7)
# ##################################################
# Sample data from jalalsons data frame:
#       Unnamed: 0       store                             name  \
# 590          590  Jalal Sons   Nivea Soft Cream 200Ml(200 Ml)
# 746          746  Jalal Sons   K&N Breast Fillet 500Gm(500 G)
# 935          935  Jalal Sons  Youngs Ckicken Spread Bbq 500Gm
# 880          880  Jalal Sons       Sufi Canola Oil Pouch 1Ltr
# 715          715  Jalal Sons  Mon Salwa Lachaydar Paratha 5Pc
# 1079        1079  Jalal Sons  Mehran Granulte Brown Sugar 1Kg
# 1081        1081  Jalal Sons      National Biryani Masala 45G
# 311          311  Jalal Sons   Kelloggs Coco Pop Chocos 375Gm
# 346          346  Jalal Sons          Quaker White Oats 500Gm
# 885          885  Jalal Sons              Sufi Ghee Tin 2.5Kg
#
#                                            product-link     price  \
# 590   https://jalalsons.com.pk/product/nivea-soft-cr...  Rs 1,094
# 746   https://jalalsons.com.pk/product/kn-breast-fil...    Rs 684
# 935   https://jalalsons.com.pk/product/youngs-ckicke...    Rs 699
# 880   https://jalalsons.com.pk/product/sufi-canola-o...    Rs 564
# 715   https://jalalsons.com.pk/product/mon-salwa-lac...    Rs 178
# 1079  https://jalalsons.com.pk/product/mehran-granul...    Rs 394
# 1081  https://jalalsons.com.pk/product/national-biry...    Rs 148
# 311   https://jalalsons.com.pk/product/kelloggs-coco...    Rs 898
# 346   https://jalalsons.com.pk/product/quaker-white-...    Rs 994
# 885   https://jalalsons.com.pk/product/sufi-ghee-tin...  Rs 1,513
#
#                       category  \
# 590                  Cosmetics
# 746               Frozen Foods
# 935    Ketchup, Sauce And Mayo
# 880               Ghee And Oil
# 715               Frozen Foods
# 1079  Spices And Miscellaneous
# 1081  Spices And Miscellaneous
# 311   Cereal, Jams And Spreads
# 346   Cereal, Jams And Spreads
# 885               Ghee And Oil
#
#                                               image_url
# 590   https://static.tossdown.com/images/71b77149-6e...
# 746   https://static.tossdown.com/images/080c7aa9-1e...
# 935   https://static.tossdown.com/images/ecc4439c-cc...
# 880   https://static.tossdown.com/images/a9345347-6d...
# 715   https://static.tossdown.com/images/bf94e75e-7a...
# 1079  https://static.tossdown.com/images/b7bfafa0-8c...
# 1081  https://static.tossdown.com/images/c1f7a393-ba...
# 311   https://static.tossdown.com/images/d364a90f-1a...
# 346   https://static.tossdown.com/images/e7f8a495-d8...
# 885   https://static.tossdown.com/images/08ba6842-b4...
# ##################################################
# categories in jalalsons data frame:
# category
# Beverages                            100
# Confectionery And Chocolates         100
# Biscuits , Crisps And Snacks         100
# Cleaning Products                    100
# Frozen Foods                         100
# Toiletries                           100
# Spices And Miscellaneous              81
# Cereal, Jams And Spreads              80
# Yoghurt, Butter, Cream And Cheese     74
# Ketchup, Sauce And Mayo               65
# Tea And Coffee                        57
# Ghee And Oil                          56
# Fresh Milk And Eggs                   53
# Tissues And Sanitary                  45
# Flour, Rice And Pulses                44
# Other Food Items                      43
# Canned Foods And Milks                38
# Baby Milk And Food                    27
# Butter                                25
# Dry Fruits And Dates                  21
# Mineral Water                         18
# Cosmetics                             18
# Diapers And Pampers                   18
# Personal Hygiene                      18
# Baking Goods                          15
# Powder Milk                           12
# Pet Food                              12
# Name: count, dtype: int64
# {'beverages---jalalsons': None, 'confectionery_and_chocolates---jalalsons': None, 'biscuits_,_crisps_and_snacks---jalalsons': None, 'cleaning_products---jalalsons': None, 'frozen_foods---jalalsons': None, 'toiletries---jalalsons': None, 'spices_and_miscellaneous---jalalsons': None, 'cereal,_jams_and_spreads---jalalsons': None, 'yoghurt,_butter,_cream_and_cheese---jalalsons': None, 'ketchup,_sauce_and_mayo---jalalsons': None, 'tea_and_coffee---jalalsons': None, 'ghee_and_oil---jalalsons': None, 'fresh_milk_and_eggs---jalalsons': None, 'tissues_and_sanitary---jalalsons': None, 'flour,_rice_and_pulses---jalalsons': None, 'other_food_items---jalalsons': None, 'canned_foods_and_milks---jalalsons': None, 'baby_milk_and_food---jalalsons': None, 'butter---jalalsons': None, 'dry_fruits_and_dates---jalalsons': None, 'mineral_water---jalalsons': None, 'cosmetics---jalalsons': None, 'diapers_and_pampers---jalalsons': None, 'personal_hygiene---jalalsons': None, 'baking_goods---jalalsons': None, 'powder_milk---jalalsons': None, 'pet_food---jalalsons': None}

# %% [markdown]
# for metro

# %%
print("shape of metro data frame:")
print(df_metro.shape)
print("#"*50)

print("Sample data from metro data frame:")
display(df_metro.sample(10))
print("#"*50)

print("categories in metro data frame:")
metro_categories=df_metro['category'].value_counts()
print(metro_categories[metro_categories>10])  # to handle NaN values

pattern=r'-+'
replacement=r'_'
metro_categories_json=dict.fromkeys([ re.sub(pattern, replacement, c.lower()) + "---metro" for c in metro_categories.index])
print(metro_categories_json)
# Out:
# shape of metro data frame:
# (2807, 7)
# ##################################################
# Sample data from metro data frame:
#       Unnamed: 0  store                               name  \
# 1699        1699  Metro         Young Natural Honey 125 GM
# 1758        1758  Metro          Adams Butter Salted 100GM
# 1687        1687  Metro      Mitchell Jam Mix Fruit 450 GM
# 2623        2623  Metro             Dawn Aloo Samosa 480gm
# 279          279  Metro       Guard Super Kernel Rice 25KG
# 2740        2740  Metro           Nestle Lactogen 1 800 GM
# 1355        1355  Metro        Everyday Tea Whitener 350GM
# 1603        1603  Metro          Pinar Cream Cheese 500 GM
# 925          925  Metro  Nutrilov Chocolate Brownie GB 40g
# 135          135  Metro       Kisan Banaspati Ghee 1 KG x5
#
#                                            product-link       price  \
# 1699  https://www.metro-online.pk/detail/dairy/break...     Rs. 370
# 1758  https://www.metro-online.pk/detail/dairy/butte...     Rs. 360
# 1687  https://www.metro-online.pk/detail/dairy/break...     Rs. 339
# 2623  https://www.metro-online.pk/detail/frozen-food...     Rs. 660
# 279   https://www.metro-online.pk/detail/cooking-ess...  Rs. 11,849
# 2740  https://www.metro-online.pk/detail/baby/baby-f...   Rs. 2,669
# 1355  https://www.metro-online.pk/detail/grocery/tea...     Rs. 719
# 1603  https://www.metro-online.pk/detail/dairy/chees...   Rs. 1,869
# 925   https://www.metro-online.pk/detail/grocery/sna...     Rs. 175
# 135   https://www.metro-online.pk/detail/cooking-ess...   Rs. 2,675
#
#                      category  \
# 1699  jams,-honey-and-spreads
# 1758                   butter
# 1687  jams,-honey-and-spreads
# 2623        samosas-and-rolls
# 279                      rice
# 2740                baby-milk
# 1355     coffee-and-whiteners
# 1603                   cheese
# 925       biscuits-and-wafers
# 135              oil-and-ghee
#
#                                               image_url
# 1699  https://www.metro-online.pk/_next/image?url=ht...
# 1758  https://www.metro-online.pk/_next/image?url=ht...
# 1687  https://www.metro-online.pk/_next/image?url=ht...
# 2623  https://www.metro-online.pk/_next/image?url=ht...
# 279   https://www.metro-online.pk/_next/image?url=ht...
# 2740  https://www.metro-online.pk/_next/image?url=ht...
# 1355  https://www.metro-online.pk/_next/image?url=ht...
# 1603  https://www.metro-online.pk/_next/image?url=ht...
# 925   https://www.metro-online.pk/_next/image?url=ht...
# 135   https://www.metro-online.pk/_next/image?url=ht...
# ##################################################
# categories in metro data frame:
# category
# oil-and-ghee                          175
# sauces-and-seasonings                 163
# crisps-and-popcorn                    137
# spices-and-herbs                      133
# kitchen-utensils-and-accessories       87
#                                      ...
# kebab-and-koftas                       12
# samosas-and-rolls                      12
# parathas                               12
# rusks                                  11
# frozen-mixed-fruits-and-vegetables     11
# Name: count, Length: 86, dtype: int64
# {'oil_and_ghee---metro': None, 'sauces_and_seasonings---metro': None, 'crisps_and_popcorn---metro': None, 'spices_and_herbs---metro': None, 'kitchen_utensils_and_accessories---metro': None, 'tea---metro': None, 'dry_fruits_and_nuts---metro': None, 'cheese---metro': None, 'cakes_and_chocolates---metro': None, 'biscuits_and_wafers---metro': None, 'uht_and_pasteurized_milk---metro': None, 'metro_post_grocery---metro': None, 'jams,_honey_and_spreads---metro': None, 'cutlery---metro': None, 'cake_mixes_and_baking_add_ons---metro': None, 'rice---metro': None, 'pots_and_pans---metro': None, 'pulses---metro': None, 'fish---metro': None, 'crockery---metro': None, 'flavored_milk---metro': None, 'tissues_and_napkins---metro': None, 'fresh_vegetables---metro': None, 'disinfectants---metro': None, 'noodles_and_pasta---metro': None, 'flour---metro': None, 'hair_colors---metro': None, 'mops_and_brooms---metro': None, 'toilet_supplies---metro': None, 'sweets_and_toffees---metro': None, 'fresh_fruits---metro': None, 'cereals---metro': None, 'jellies_and_custards---metro': None, 'coffee_and_whiteners---metro': None, 'traditional_mixes---metro': None, 'school_essentials---metro': None, 'butter---metro': None, 'powdered_milk---metro': None, 'pickles_and_olives---metro': None, 'plain_eggs---metro': None, 'shoe_polish---metro': None, 'plain_yogurt_and_flavored_yogurt---metro': None, 'cream---metro': None, 'office_supplies---metro': None, 'mutton---metro': None, 'fabric_care---metro': None, 'beef---metro': None, 'sugar---metro': None, 'baby_milk---metro': None, 'diapers_and_wipes---metro': None, 'ice_cream---metro': None, 'breads---metro': None, 'frozen_meat---metro': None, 'frozen_fries---metro': None, 'anti_perspirants---metro': None, 'body_sprays_and_body_mists---metro': None, 'insecticides---metro': None, 'disposables---metro': None, 'dishwashing_bars---metro': None, 'water---metro': None, 'nutritional_drinks---metro': None, 'juices---metro': None, 'dishwashing_liquids---metro': None, 'detergents_and_laundry_soaps---metro': None, 'conditioners---metro': None, 'shampoos---metro': None, 'oils_and_serums---metro': None, 'lotions_and_sunscreen---metro': None, 'antibacterial---metro': None, 'creams---metro': None, 'facewashes---metro': None, 'soft_drinks---metro': None, 'women_care---metro': None, 'men_grooming---metro': None, 'tooth_pastes---metro': None, 'tooth_brushes---metro': None, 'fragrant---metro': None, 'hand_and_body_washes---metro': None, 'instant_drinks---metro': None, 'sponges---metro': None, 'nuggets_and_snacks---metro': None, 'kebab_and_koftas---metro': None, 'samosas_and_rolls---metro': None, 'parathas---metro': None, 'rusks---metro': None, 'frozen_mixed_fruits_and_vegetables---metro': None, 'chicken---metro': None, 'prawns_and_crabs---metro': None, 'margarine---metro': None, 'canned_fruits---metro': None, 'cookies---metro': None, 'o.t.c_medicines---metro': None, 'red_syrups---metro': None, 'glassware---metro': None, 'air_sprays---metro': None, 'canned_vegetables---metro': None, 'bins_and_buckets---metro': None, 'jellies_and_marshmallows---metro': None, 'storage_containers---metro': None, 'squashes---metro': None, 'buns---metro': None, 'sausages---metro': None, 'frozen_seafood---metro': None, 'baby_cereals---metro': None, 'fine_life---metro': None, 'hangers_and_accessories---metro': None, 'iced_tea_and_coffee---metro': None, 'ok---metro': None, 'metro_chef---metro': None, 'brown_eggs---metro': None, 'wraps_and_pitta---metro': None, 'metro_professionals---metro': None}

# %%
print("Total categories across all shops:")
print(len(metro_categories_json)+len(fateh_categories_json)+len(imtiaz_categories_json)+len(jalalsons_categories_json))
# Out:
# Total categories across all shops:
# 215

# %% [markdown]
# mapping categories across the stores to a common category

# %%
category_mapping = {
    'air_fresheners_&_home_fragrances---imtiaz': 'Home Fragrances',
    'air_sprays---metro': 'Home Fragrances',
    'anti_perspirants---metro': 'Personal Care',
    'antibacterial---metro': 'Personal Care',
    'baby_cereals---metro': 'Baby Food',
    'baby_feeding_accessories---imtiaz': 'Baby Care',
    'baby_food---fateh': 'Baby Food',
    'baby_food---imtiaz': 'Baby Food',
    'baby_milk---metro': 'Baby Food',
    'baby_milk_and_food---jalalsons': 'Baby Food',
    'baking_accessories---fateh': 'Baking Supplies',
    'baking_chocolates---fateh': 'Baking Supplies',
    'baking_goods---jalalsons': 'Baking Supplies',
    'baking_items---fateh': 'Baking Supplies',
    'beef---metro': 'Meat',
    'beverages---jalalsons': 'Beverages',
    'bins_and_buckets---metro': 'Home & Kitchen',
    'biscuits---fateh': 'Snacks',
    'biscuits_&_wafers---imtiaz': 'Snacks',
    'biscuits_,_crisps_and_snacks---jalalsons': 'Snacks',
    'biscuits_and_wafers---metro': 'Snacks',
    'body_sprays_and_body_mists---metro': 'Personal Care',
    'bread---fateh': 'Bakery',
    'breads---metro': 'Bakery',
    'buns---metro': 'Bakery',
    'butter---fateh': 'Dairy',
    'butter---jalalsons': 'Dairy',
    'butter---metro': 'Dairy',
    'cake_mixes_and_baking_add_ons---metro': 'Baking Supplies',
    'cakes_and_chocolates---metro': 'Confectionery',
    'candies_&_bubble_gums---fateh': 'Confectionery',
    'canned/bottled_foods---imtiaz': 'Canned Foods',
    'canned_foods_and_milks---jalalsons': 'Canned Foods',
    'canned_fruits---metro': 'Canned Foods',
    'canned_vegetables---metro': 'Canned Foods',
    'carbonated_soft_drinks---imtiaz': 'Beverages',
    'cereal,_jams_and_spreads---jalalsons': 'Breakfast Foods',
    'cereals---fateh': 'Breakfast Foods',
    'cereals---metro': 'Breakfast Foods',
    'cereals_&_oats---imtiaz': 'Breakfast Foods',
    'cheese---fateh': 'Dairy',
    'cheese---metro': 'Dairy',
    'chicken---metro': 'Meat',
    'chips_&_nimko---fateh': 'Snacks',
    'chocolates---fateh': 'Confectionery',
    'cleaning---imtiaz': 'Cleaning Supplies',
    'cleaning_products---jalalsons': 'Cleaning Supplies',
    'coffee---fateh': 'Beverages',
    'coffee---imtiaz': 'Beverages',
    'coffee_and_whiteners---metro': 'Beverages',
    'conditioners---metro': 'Personal Care',
    'confectionery_and_chocolates---jalalsons': 'Confectionery',
    'cookies---metro': 'Snacks',
    'cosmetics---jalalsons': 'Personal Care',
    'cream---metro': 'Dairy',
    'creams---metro': 'Dairy',
    'crisps_and_popcorn---metro': 'Snacks',
    'crockery---metro': 'Home & Kitchen',
    'cutlery---metro': 'Home & Kitchen',
    'dairy_creams---fateh': 'Dairy',
    'dessert---imtiaz': 'Desserts',
    'detergents_and_laundry_soaps---metro': 'Cleaning Supplies',
    'diapers_&_pants---imtiaz': 'Baby Care',
    'diapers_and_pampers---jalalsons': 'Baby Care',
    'diapers_and_wipes---metro': 'Baby Care',
    'dishwashing_bars---metro': 'Cleaning Supplies',
    'dishwashing_liquids---metro': 'Cleaning Supplies',
    'disinfectants---metro': 'Cleaning Supplies',
    'disposable---imtiaz': 'Disposables',
    'disposables---metro': 'Disposables',
    'drinking_powders---fateh': 'Beverages',
    'drinking_water---fateh': 'Beverages',
    'dry_fruits---imtiaz': 'Dry Fruits & Nuts',
    'dry_fruits_&_dates---fateh': 'Dry Fruits & Nuts',
    'dry_fruits_and_dates---jalalsons': 'Dry Fruits & Nuts',
    'dry_fruits_and_nuts---metro': 'Dry Fruits & Nuts',
    'edible_oil_&_ghee---imtiaz': 'Cooking Oils',
    'eggs---fateh': 'Dairy & Eggs',
    'fabric_care---metro': 'Cleaning Supplies',
    'facewashes---metro': 'Personal Care',
    'fine_life---metro': 'Store Brand',
    'fish---metro': 'Seafood',
    'flavored_milk---metro': 'Dairy',
    'flavoured_milk---fateh': 'Dairy',
    'flavoured_milk---imtiaz': 'Dairy',
    'flour,_rice_and_pulses---jalalsons': 'Staples',
    'flour---fateh': 'Staples',
    'flour---imtiaz': 'Staples',
    'flour---metro': 'Staples',
    'fragrant---metro': 'Home Fragrances',
    'fresh_fruits---metro': 'Fresh Produce',
    'fresh_milk_and_eggs---jalalsons': 'Dairy & Eggs',
    'fresh_vegetables---metro': 'Fresh Produce',
    'frozen_foods---jalalsons': 'Frozen Foods',
    'frozen_fries---fateh': 'Frozen Foods',
    'frozen_fries---metro': 'Frozen Foods',
    'frozen_items---fateh': 'Frozen Foods',
    'frozen_meat---metro': 'Frozen Foods',
    'frozen_mixed_fruits_and_vegetables---metro': 'Frozen Foods',
    'frozen_seafood---metro': 'Frozen Foods',
    'ghee---fateh': 'Cooking Oils',
    'ghee_and_oil---jalalsons': 'Cooking Oils',
    'glassware---metro': 'Home & Kitchen',
    'hair_colors---metro': 'Personal Care',
    'hand_and_body_washes---metro': 'Personal Care',
    'hangers_and_accessories---metro': 'Home & Kitchen',
    'honey---fateh': 'Spreads',
    'hygiene---imtiaz': 'Personal Care',
    'ice_cream---fateh': 'Frozen Foods',
    'ice_cream---metro': 'Frozen Foods',
    'iced_tea_and_coffee---metro': 'Beverages',
    'imported_drinks_&_juices---fateh': 'Beverages',
    'insecticides---metro': 'Home Care',
    'instant_drinks---metro': 'Beverages',
    'instant_tea_&_coffee---imtiaz': 'Beverages',
    'jams,_honey_and_spreads---metro': 'Spreads',
    'jams---fateh': 'Spreads',
    'jellies_and_custards---metro': 'Desserts',
    'juices---metro': 'Beverages',
    'juices_&_nectars---imtiaz': 'Beverages',
    'kebab_and_koftas---metro': 'Meat',
    'ketchup,_sauce_and_mayo---jalalsons': 'Condiments',
    'kitchen_utensils_and_accessories---metro': 'Home & Kitchen',
    'laundry---imtiaz': 'Cleaning Supplies',
    'liquid_tin_milk---fateh': 'Dairy',
    'local_drinks---fateh': 'Beverages',
    'lotions_and_sunscreen---metro': 'Personal Care',
    'make_to_drink---imtiaz': 'Beverages',
    'margarine---fateh': 'Dairy',
    'margarine---metro': 'Dairy',
    'mayo_&_spreads---fateh': 'Condiments',
    'men_grooming---metro': 'Personal Care',
    'metro_chef---metro': 'Store Brand',
    'metro_post_grocery---metro': 'Store Brand',
    'metro_professionals---metro': 'Store Brand',
    'milk---fateh': 'Dairy',
    'milk---imtiaz': 'Dairy',
    'milk_powder_&_whitener---fateh': 'Dairy',
    'mineral_water---jalalsons': 'Beverages',
    'mops_and_brooms---metro': 'Cleaning Supplies',
    'mutton---metro': 'Meat',
    'noodles_&_pasta---fateh': 'Pasta & Noodles',
    'noodles_&_pasta---imtiaz': 'Pasta & Noodles',
    'noodles_and_pasta---metro': 'Pasta & Noodles',
    'nuggets_and_snacks---metro': 'Frozen Foods',
    'nutritional_drinks---metro': 'Beverages',
    'o.t.c_medicines---metro': 'Health & Wellness',
    'office_supplies---metro': 'Home & Kitchen',
    'oil_and_ghee---metro': 'Cooking Oils',
    'oils---fateh': 'Cooking Oils',
    'oils_and_serums---metro': 'Personal Care',
    'ok---metro': 'Store Brand',
    'olive_oil---fateh': 'Cooking Oils',
    'oral_care---imtiaz': 'Personal Care',
    'other_food_items---jalalsons': 'Miscellaneous',
    'parathas---metro': 'Frozen Foods',
    'personal_hygiene---jalalsons': 'Personal Care',
    'pet_food---jalalsons': 'Pet Care',
    'pickle_&_vinegar---fateh': 'Condiments',
    'pickles_and_olives---metro': 'Condiments',
    'plain_eggs---metro': 'Dairy & Eggs',
    'plain_yogurt_and_flavored_yogurt---metro': 'Dairy',
    'popcorn---fateh': 'Snacks',
    'pots_and_pans---metro': 'Home & Kitchen',
    'powder_milk---jalalsons': 'Dairy',
    'powdered_milk---metro': 'Dairy',
    'prawns_and_crabs---metro': 'Seafood',
    'pulses---metro': 'Staples',
    'pulses_&_grains---imtiaz': 'Staples',
    'raita---fateh': 'Dairy',
    'red_syrups---metro': 'Beverages',
    'rice---imtiaz': 'Staples',
    'rice---metro': 'Staples',
    'rice_products---fateh': 'Staples',
    'rusks---metro': 'Bakery',
    'rusks_&_buns---fateh': 'Bakery',
    'salt,_spices_&_herbs---imtiaz': 'Spices & Seasonings',
    'salt---fateh': 'Spices & Seasonings',
    'samosas_and_rolls---metro': 'Frozen Foods',
    'sauces,_dressings_&_seasonings---imtiaz': 'Condiments',
    'sauces_&_soups---fateh': 'Condiments',
    'sauces_and_seasonings---metro': 'Condiments',
    'sausages---metro': 'Meat',
    'school_essentials---metro': 'Home & Kitchen',
    'shampoos---metro': 'Personal Care',
    'shoe_polish---metro': 'Home Care',
    'skin_care---imtiaz': 'Personal Care',
    'soft_drinks---metro': 'Beverages',
    'spices_and_herbs---metro': 'Spices & Seasonings',
    'spices_and_miscellaneous---jalalsons': 'Spices & Seasonings',
    'sponges---metro': 'Cleaning Supplies',
    'sports_drink---imtiaz': 'Beverages',
    'spreads---imtiaz': 'Spreads',
    'squashes---fateh': 'Beverages',
    'squashes---metro': 'Beverages',
    'storage_containers---metro': 'Home & Kitchen',
    'sugar---fateh': 'Staples',
    'sugar---imtiaz': 'Staples',
    'sugar---metro': 'Staples',
    'sweets_and_toffees---metro': 'Confectionery',
    'tea---imtiaz': 'Beverages',
    'tea---metro': 'Beverages',
    'tea_and_coffee---jalalsons': 'Beverages',
    'tea_whiteners---imtiaz': 'Beverages',
    'teas---fateh': 'Beverages',
    'tin_foods---fateh': 'Canned Foods',
    'tissue---imtiaz': 'Disposables',
    'tissues_and_napkins---metro': 'Disposables',
    'tissues_and_sanitary---jalalsons': 'Disposables',
    'toilet_supplies---metro': 'Personal Care',
    'toiletries---jalalsons': 'Personal Care',
    'tooth_brushes---metro': 'Personal Care',
    'tooth_pastes---metro': 'Personal Care',
    'traditional_mixes---metro': 'Cooking Ingredients',
    'uht_and_pasteurized_milk---metro': 'Dairy',
    'water---imtiaz': 'Beverages',
    'water---metro': 'Beverages',
    'women_care---metro': 'Personal Care',
    'wraps_and_pitta---metro': 'Bakery',
    'yoghurt,_butter,_cream_and_cheese---jalalsons': 'Dairy',
    'yogurt---fateh': 'Dairy'
}

# Print summary of common categories
common_categories = set(category_mapping.values())
print(f"Total store-specific categories: {len(category_mapping)}")
print(f"Total common categories: {len(common_categories)}")
print(f"\nCommon categories: {sorted(common_categories)}")
# Out:
# Total store-specific categories: 221
# Total common categories: 34
#
# Common categories: ['Baby Care', 'Baby Food', 'Bakery', 'Baking Supplies', 'Beverages', 'Breakfast Foods', 'Canned Foods', 'Cleaning Supplies', 'Condiments', 'Confectionery', 'Cooking Ingredients', 'Cooking Oils', 'Dairy', 'Dairy & Eggs', 'Desserts', 'Disposables', 'Dry Fruits & Nuts', 'Fresh Produce', 'Frozen Foods', 'Health & Wellness', 'Home & Kitchen', 'Home Care', 'Home Fragrances', 'Meat', 'Miscellaneous', 'Pasta & Noodles', 'Personal Care', 'Pet Care', 'Seafood', 'Snacks', 'Spices & Seasonings', 'Spreads', 'Staples', 'Store Brand']

# %%
df_fateh.category=df_fateh.category.str.lower()
df_fateh.category=[re.sub(r' +',r'_',c)+"---fateh" for c in df_fateh.category]

df_imtiaz.category=df_imtiaz.category.str.lower()
df_imtiaz.category=[re.sub(r' +',r'_',c)+"---imtiaz" for c in df_imtiaz.category]

df_jalalsons.category=df_jalalsons.category.str.lower()
df_jalalsons.category=[re.sub(r' +',r'_',c)+"---jalalsons" for c in df_jalalsons.category]

df_metro.category=df_metro.category.str.lower()
df_metro.category=[re.sub(r'-+',r'_',c)+"---metro" for c in df_metro.category]


df_fateh['common_category']=df_fateh['category'].map(category_mapping)
df_imtiaz['common_category']=df_imtiaz['category'].map(category_mapping)
df_jalalsons['common_category']=df_jalalsons['category'].map(category_mapping)
df_metro['common_category']=df_metro['category'].map(category_mapping)

# %%
print(df_fateh[['category','common_category']].sample(20))
print(df_imtiaz[['category','common_category']].sample(20))
print(df_jalalsons[['category','common_category']].sample(20))
print(df_metro[['category','common_category']].sample(20))
# Out:
#                               category    common_category
# 3442        baking_accessories---fateh    Baking Supplies
# 574                       milk---fateh              Dairy
# 2192            mayo_&_spreads---fateh         Condiments
# 1990            sauces_&_soups---fateh         Condiments
# 759                  baby_food---fateh          Baby Food
# 3301          pickle_&_vinegar---fateh         Condiments
# 4514                 ice_cream---fateh       Frozen Foods
# 2493     candies_&_bubble_gums---fateh      Confectionery
# 3828                   popcorn---fateh             Snacks
# 3154  imported_drinks_&_juices---fateh          Beverages
# 2297           noodles_&_pasta---fateh    Pasta & Noodles
# 124         dry_fruits_&_dates---fateh  Dry Fruits & Nuts
# 3045  imported_drinks_&_juices---fateh          Beverages
# 1652                  biscuits---fateh             Snacks
# 3528              baking_items---fateh    Baking Supplies
# 4253                    yogurt---fateh              Dairy
# 1749                chocolates---fateh      Confectionery
# 2922                    coffee---fateh          Beverages
# 3115  imported_drinks_&_juices---fateh          Beverages
# 3260          pickle_&_vinegar---fateh         Condiments
#                                       category      common_category
# 36                   juices_&_nectars---imtiaz            Beverages
# 182                butter_&_margarine---imtiaz                  NaN
# 176                    flavoured_milk---imtiaz                Dairy
# 53                   juices_&_nectars---imtiaz            Beverages
# 87                    pulses_&_grains---imtiaz              Staples
# 42                   juices_&_nectars---imtiaz            Beverages
# 122                   noodles_&_pasta---imtiaz      Pasta & Noodles
# 244  air_fresheners_&_home_fragrances---imtiaz      Home Fragrances
# 145              salt,_spices_&_herbs---imtiaz  Spices & Seasonings
# 234                            tissue---imtiaz          Disposables
# 118                   noodles_&_pasta---imtiaz      Pasta & Noodles
# 30                   juices_&_nectars---imtiaz            Beverages
# 201          baby_feeding_accessories---imtiaz            Baby Care
# 239                            tissue---imtiaz          Disposables
# 245  air_fresheners_&_home_fragrances---imtiaz      Home Fragrances
# 198          baby_feeding_accessories---imtiaz            Baby Care
# 227                           laundry---imtiaz    Cleaning Supplies
# 189                butter_&_margarine---imtiaz                  NaN
# 64                              water---imtiaz            Beverages
# 196          baby_feeding_accessories---imtiaz            Baby Care
#                                            category      common_category
# 619                 diapers_and_pampers---jalalsons            Baby Care
# 1250                         toiletries---jalalsons        Personal Care
# 1093           spices_and_miscellaneous---jalalsons  Spices & Seasonings
# 1107           spices_and_miscellaneous---jalalsons  Spices & Seasonings
# 7                                butter---jalalsons                Dairy
# 1273                         toiletries---jalalsons        Personal Care
# 217        biscuits_,_crisps_and_snacks---jalalsons               Snacks
# 1391  yoghurt,_butter,_cream_and_cheese---jalalsons                Dairy
# 197        biscuits_,_crisps_and_snacks---jalalsons               Snacks
# 67                            beverages---jalalsons            Beverages
# 1169                     tea_and_coffee---jalalsons            Beverages
# 1382  yoghurt,_butter,_cream_and_cheese---jalalsons                Dairy
# 1137           spices_and_miscellaneous---jalalsons  Spices & Seasonings
# 695                        frozen_foods---jalalsons         Frozen Foods
# 56                            beverages---jalalsons            Beverages
# 457        confectionery_and_chocolates---jalalsons        Confectionery
# 1351  yoghurt,_butter,_cream_and_cheese---jalalsons                Dairy
# 850                        ghee_and_oil---jalalsons         Cooking Oils
# 21                               butter---jalalsons                Dairy
# 1281                         toiletries---jalalsons        Personal Care
#                                       category      common_category
# 1704           jams,_honey_and_spreads---metro              Spreads
# 545                   spices_and_herbs---metro  Spices & Seasonings
# 2126                           cutlery---metro       Home & Kitchen
# 1094              cakes_and_chocolates---metro        Confectionery
# 1290                               tea---metro            Beverages
# 2292                      insecticides---metro            Home Care
# 2119                           cutlery---metro       Home & Kitchen
# 2020  kitchen_utensils_and_accessories---metro       Home & Kitchen
# 2655                       frozen_meat---metro         Frozen Foods
# 2107                           cutlery---metro       Home & Kitchen
# 1810                     disinfectants---metro    Cleaning Supplies
# 2544                     tooth_brushes---metro        Personal Care
# 579                   spices_and_herbs---metro  Spices & Seasonings
# 1208                pickles_and_olives---metro           Condiments
# 668                       fresh_fruits---metro        Fresh Produce
# 1206                pickles_and_olives---metro           Condiments
# 140                       oil_and_ghee---metro         Cooking Oils
# 657                   spices_and_herbs---metro  Spices & Seasonings
# 1726           jams,_honey_and_spreads---metro              Spreads
# 2266                       disposables---metro          Disposables

# %%
#df_fateh.to_csv("al-fateh-products-with-common-categories.csv", index=False)
#df_imtiaz.to_csv("Imtiaz-products-with-common-categories.csv", index=False)
#df_jalalsons.to_csv("jalal-sons-products-with-common-categories.csv", index=False)
#df_metro.to_csv("metro-products-with-common-categories.csv", index=False)

# %%
print("Common category value counts:")
print("----------------------------")
print("For df_fateh:")
print(df_fateh["common_category"].value_counts())
print("For df_imtiaz:")
print(df_imtiaz["common_category"].value_counts())
print("For df_jalalsons:")
print(df_jalalsons["common_category"].value_counts())
print("For df_metro:")
print(df_metro["common_category"].value_counts())
# Out:
# Common category value counts:
# ----------------------------
# For df_fateh:
# common_category
# Beverages              844
# Condiments             583
# Snacks                 426
# Dairy                  364
# Frozen Foods           353
# Baking Supplies        338
# Confectionery          296
# Cooking Oils           235
# Pasta & Noodles        183
# Dry Fruits & Nuts      171
# Canned Foods           169
# Baby Food              163
# Breakfast Foods        153
# Spreads                144
# Staples                130
# Bakery                  75
# Spices & Seasonings     40
# Dairy & Eggs             9
# Name: count, dtype: int64
# For df_imtiaz:
# common_category
# Beverages              86
# Pasta & Noodles        30
# Spices & Seasonings    24
# Staples                21
# Dairy                  15
# Baby Care              14
# Baby Food              12
# Disposables            10
# Cleaning Supplies       8
# Personal Care           5
# Home Fragrances         5
# Snacks                  1
# Name: count, dtype: int64
# For df_jalalsons:
# common_category
# Beverages              175
# Personal Care          136
# Dairy                  111
# Cleaning Supplies      100
# Snacks                 100
# Confectionery          100
# Frozen Foods           100
# Spices & Seasonings     81
# Breakfast Foods         80
# Condiments              65
# Cooking Oils            56
# Dairy & Eggs            53
# Disposables             45
# Staples                 44
# Miscellaneous           43
# Canned Foods            38
# Baby Food               27
# Dry Fruits & Nuts       21
# Baby Care               18
# Baking Supplies         15
# Pet Care                12
# Name: count, dtype: int64
# For df_metro:
# common_category
# Home & Kitchen         282
# Dairy                  260
# Personal Care          217
# Snacks                 203
# Beverages              182
# Condiments             180
# Cooking Oils           175
# Staples                138
# Spices & Seasonings    133
# Cleaning Supplies      128
# Confectionery           97
# Frozen Foods            88
# Dry Fruits & Nuts       73
# Fresh Produce           68
# Store Brand             59
# Seafood                 54
# Disposables             53
# Meat                    52
# Spreads                 49
# Baking Supplies         47
# Pasta & Noodles         39
# Bakery                  30
# Home Care               28
# Breakfast Foods         27
# Desserts                25
# Cooking Ingredients     20
# Home Fragrances         20
# Canned Foods            18
# Dairy & Eggs            17
# Baby Food               16
# Baby Care               12
# Health & Wellness       10
# Name: count, dtype: int64

# %% [markdown]
# selecting the common categories across all the stores for model training

# %%
common_categories_from_all_stores = set(df_fateh['common_category']).intersection(set(df_imtiaz['common_category'])).intersection(set(df_jalalsons['common_category'])).intersection(set(df_metro['common_category']))

all_common_categories = set(df_fateh['common_category']).union(set(df_imtiaz['common_category'])).union(set(df_jalalsons['common_category'])).union(set(df_metro['common_category']))

print("Number of common categories across all stores:")
print(len(common_categories_from_all_stores))
print("Number of all categories across the stores:")
print(len(all_common_categories))

print("Common categories across all stores:")
print(common_categories_from_all_stores)
print("Categories not present in all stores:")
print(all_common_categories.difference(common_categories_from_all_stores))
# Out:
# Number of common categories across all stores:
# 6
# Number of all categories across the stores:
# 35
# Common categories across all stores:
# {'Baby Food', 'Staples', 'Dairy', 'Beverages', 'Spices & Seasonings', 'Snacks'}
# Categories not present in all stores:
# {'Miscellaneous', 'Store Brand', 'Bakery', 'Frozen Foods', 'Dairy & Eggs', 'Health & Wellness', 'Cleaning Supplies', 'Pasta & Noodles', 'Home & Kitchen', nan, 'Breakfast Foods', 'Personal Care', 'Fresh Produce', 'Baking Supplies', 'Spreads', 'Confectionery', 'Cooking Ingredients', 'Condiments', 'Dry Fruits & Nuts', 'Pet Care', 'Home Fragrances', 'Disposables', 'Seafood', 'Canned Foods', 'Desserts', 'Cooking Oils', 'Baby Care', 'Meat', 'Home Care'}

# %%
common_fateh=df_fateh[df_fateh['common_category'].isin(common_categories_from_all_stores)]
a=common_fateh.groupby('common_category').agg(length=("name","count"))

b=df_fateh[df_fateh['common_category'].isin(all_common_categories.difference(common_categories_from_all_stores))].groupby('common_category').agg(length=("name","count"))

print("Categories present in all stores:")
print(a)
print("Categories not present in all stores:")
print(b)
# Out:
# Categories present in all stores:
#                      length
# common_category
# Baby Food               163
# Beverages               844
# Dairy                   364
# Snacks                  426
# Spices & Seasonings      40
# Staples                 130
# Categories not present in all stores:
#                    length
# common_category
# Bakery                 75
# Baking Supplies       338
# Breakfast Foods       153
# Canned Foods          169
# Condiments            583
# Confectionery         296
# Cooking Oils          235
# Dairy & Eggs            9
# Dry Fruits & Nuts     171
# Frozen Foods          353
# Pasta & Noodles       183
# Spreads               144

# %%
common_jalalsons=df_jalalsons[df_jalalsons['common_category'].isin(common_categories_from_all_stores)]
a=common_jalalsons.groupby('common_category').agg(length=("name","count"))

b=df_jalalsons[df_jalalsons['common_category'].isin(all_common_categories.difference(common_categories_from_all_stores))].groupby('common_category').agg(length=("name","count"))

print("Categories present in all stores:")
print(a)
print("Categories not present in all stores:")
print(b)
# Out:
# Categories present in all stores:
#                      length
# common_category
# Baby Food                27
# Beverages               175
# Dairy                   111
# Snacks                  100
# Spices & Seasonings      81
# Staples                  44
# Categories not present in all stores:
#                    length
# common_category
# Baby Care              18
# Baking Supplies        15
# Breakfast Foods        80
# Canned Foods           38
# Cleaning Supplies     100
# Condiments             65
# Confectionery         100
# Cooking Oils           56
# Dairy & Eggs           53
# Disposables            45
# Dry Fruits & Nuts      21
# Frozen Foods          100
# Miscellaneous          43
# Personal Care         136
# Pet Care               12

# %%
common_metro=df_metro[df_metro['common_category'].isin(common_categories_from_all_stores)]
a=common_metro.groupby('common_category').agg(length=("name","count"))
b=df_metro[df_metro['common_category'].isin(all_common_categories.difference(common_categories_from_all_stores))].groupby('common_category').agg(length=("name","count"))

print("Categories present in all stores:")
print(a)
print("Categories not present in all stores:")
print(b)
# Out:
# Categories present in all stores:
#                      length
# common_category
# Baby Food                16
# Beverages               182
# Dairy                   260
# Snacks                  203
# Spices & Seasonings     133
# Staples                 138
# Categories not present in all stores:
#                      length
# common_category
# Baby Care                12
# Bakery                   30
# Baking Supplies          47
# Breakfast Foods          27
# Canned Foods             18
# Cleaning Supplies       128
# Condiments              180
# Confectionery            97
# Cooking Ingredients      20
# Cooking Oils            175
# Dairy & Eggs             17
# Desserts                 25
# Disposables              53
# Dry Fruits & Nuts        73
# Fresh Produce            68
# Frozen Foods             88
# Health & Wellness        10
# Home & Kitchen          282
# Home Care                28
# Home Fragrances          20
# Meat                     52
# Pasta & Noodles          39
# Personal Care           217
# Seafood                  54
# Spreads                  49
# Store Brand              59

# %%
    
common_imtiaz=df_imtiaz[df_imtiaz['common_category'].isin(common_categories_from_all_stores)]
a=common_imtiaz.groupby('common_category').agg(length=("name","count"))

b=df_imtiaz[df_imtiaz['common_category'].isin(all_common_categories.difference(common_categories_from_all_stores))].groupby('common_category').agg(length=("name","count"))

print("Categories present in all stores:")
print(a)
print("Categories not present in all stores:")
print(b)
# Out:
# Categories present in all stores:
#                      length
# common_category
# Baby Food                12
# Beverages                86
# Dairy                    15
# Snacks                    1
# Spices & Seasonings      24
# Staples                  21
# Categories not present in all stores:
#                    length
# common_category
# Baby Care              14
# Cleaning Supplies       8
# Disposables            10
# Home Fragrances         5
# Pasta & Noodles        30
# Personal Care           5

# %%
df=pd.concat([common_fateh, common_jalalsons, common_metro, common_imtiaz],ignore_index=True)
df.to_csv("grocery_products_canonicalized_categories.csv",index=False)
